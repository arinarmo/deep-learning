# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:02, 12.2MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import math
import random

def subsample(bag, t):
    word_freqs = Counter(bag)
    total = len(bag)
    for word in bag:
        p_drop = 1 - math.sqrt(t/(word_freqs[word]/total))
        if random.random() > p_drop:
            yield word

train_words = list(subsample(int_words, 1e-5))
len(train_words)
# Out:
# 4627731

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    random_window = random.randint(1, window_size)
    start = idx - random_window if idx - random_window > 0 else 0
    
    return list(set(words[start:idx] + words[(idx+1):(idx+random_window+1)]))

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None])
    labels = tf.placeholder(tf.int32, [None, None])

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.truncated_normal([n_vocab, n_embedding], stddev=.1))# create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs)# use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding], stddev=.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.truncated_normal([n_vocab], stddev=.1)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %%
# ?tf.nn.sampled_softmax_loss

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.4056 0.0756 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.3748 0.0748 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.2992 0.0744 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.3757 0.0746 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.2834 0.0747 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.2618 0.0750 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.2394 0.0744 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.1137 0.0749 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 4.9625 0.0752 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 4.8529 0.0756 sec/batch
# Nearest to use: are, line, specifically, big, during, on, move, those,
# Nearest to state: model, into, nation, engaged, big, went, order, story,
# Nearest to but: their, lead, it, government, own, be, others, when,
# Nearest to where: first, directors, player, also, refers, ever, parliament, respect,
# Nearest to than: we, only, centuries, several, during, much, below, in,
# Nearest to united: sold, hollywood, form, during, retained, half, early, population,
# Nearest to at: in, came, remain, blue, shown, cost, present, and,
# Nearest to s: was, full, since, become, of, record, from, in,
# Nearest to accepted: a, whom, port, most, put, simply, first, form,
# Nearest to active: a, becoming, some, party, about, wait, go, either,
# Nearest to discovered: recorded, therefore, is, have, a, become, this, oldest,
# Nearest to centre: handed, spread, started, outcome, competition, close, whether, records,
# Nearest to taking: and, front, from, late, situation, hope, joined, half,
# Nearest to lived: we, about, remains, than, after, work, effects, same,
# Nearest to troops: france, during, apart, after, version, rate, th, old,
# Nearest to resources: despite, under, also, moved, x, whether, gallery, came,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 4.8293 0.0769 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 4.7525 0.0758 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 4.7316 0.0757 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 4.7084 0.0759 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 4.6830 0.0755 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 4.6581 0.0760 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 4.6806 0.0765 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 4.6826 0.0778 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.6722 0.0762 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.6504 0.0768 sec/batch
# Nearest to use: very, much, it, physical, are, information, these, is,
# Nearest to state: administration, nation, maintains, independence, fifty, employment, elected, estates,
# Nearest to but: it, of, as, the, have, others, that, with,
# Nearest to where: refers, respect, all, is, a, angles, this, number,
# Nearest to than: much, defining, only, increase, a, use, completely, overall,
# Nearest to united: states, national, british, washington, during, demographics, coast, hollywood,
# Nearest to at: in, and, after, early, again, the, filmed, failed,
# Nearest to s: was, in, and, one, of, the, full, three,
# Nearest to accepted: a, simply, but, all, yet, frequently, that, most,
# Nearest to active: wait, some, becoming, wto, of, there, a, authorized,
# Nearest to discovered: a, therefore, this, been, of, an, is, have,
# Nearest to centre: school, spread, residential, roads, colombia, financing, park, embracing,
# Nearest to taking: demonstrations, situation, height, sorting, checking, necessarily, from, permitted,
# Nearest to lived: the, was, today, after, in, s, judged, quoted,
# Nearest to troops: france, during, th, britain, after, colony, world, paris,
# Nearest to resources: checks, specifications, climatic, accumulation, increased, exclusion, sharing, educational,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.6570 0.0781 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.6321 0.0762 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.6518 0.0765 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.6369 0.0768 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.6174 0.0762 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.6238 0.0771 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.6166 0.0769 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.5988 0.0758 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.5899 0.0771 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.5776 0.0764 sec/batch
# Nearest to use: or, systems, efficiently, these, can, multiple, data, are,
# Nearest to state: administration, government, elected, parliament, independent, electoral, minister, executive,
# Nearest to but: it, that, in, to, have, of, their, as,
# Nearest to where: a, is, also, number, an, respect, this, as,
# Nearest to than: more, be, are, only, it, much, this, or,
# Nearest to united: states, national, british, country, coast, union, republican, germany,
# Nearest to at: in, and, after, the, early, during, first, was,
# Nearest to s: was, one, in, and, the, of, zero, a,
# Nearest to accepted: that, to, what, put, simply, but, most, not,
# Nearest to active: a, since, there, wait, of, attempts, many, devalued,
# Nearest to discovered: this, a, it, is, an, been, features, same,
# Nearest to centre: financing, located, south, cities, ceremonial, moved, shares, busiest,
# Nearest to taking: from, front, and, however, situation, in, demonstrations, coveted,
# Nearest to lived: was, reign, after, daughter, brother, king, death, th,
# Nearest to troops: france, army, war, britain, during, invasion, soviet, forces,
# Nearest to resources: increased, checks, significant, highest, funding, dollars, sharing, climatic,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.6037 0.0787 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.5880 0.0778 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.5573 0.0765 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.5214 0.0765 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.5179 0.0770 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.4978 0.0768 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.5046 0.0769 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.5604 0.0770 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.5402 0.0772 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.5000 0.0765 sec/batch
# Nearest to use: multiple, common, efficiently, used, or, can, sometimes, allow,
# Nearest to state: administration, government, approved, states, constitution, agreement, legislative, executive,
# Nearest to but: it, that, however, with, have, their, in, when,
# Nearest to where: a, also, then, is, number, an, left, long,
# Nearest to than: more, it, this, have, only, which, are, much,
# Nearest to united: states, national, member, union, nations, republican, referendum, refugees,
# Nearest to at: in, first, for, once, was, and, with, after,
# Nearest to s: was, in, on, the, a, first, one, of,
# Nearest to accepted: that, what, those, not, view, seek, as, necessary,
# Nearest to active: a, of, providing, there, since, many, result, attempts,
# Nearest to discovered: this, it, same, invented, known, is, angles, therefore,
# Nearest to centre: streets, located, city, residential, historic, roads, busiest, cities,
# Nearest to taking: with, front, and, in, the, grounds, to, hope,
# Nearest to lived: death, who, daughters, daughter, brother, was, whom, sons,
# Nearest to troops: forces, army, invasion, war, france, invaded, seized, soviet,
# Nearest to resources: increased, arable, pastures, infrastructure, economy, highest, irrigated, industrial,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.4781 0.0771 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.4578 0.0777 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.4339 0.0772 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.4308 0.0769 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.4236 0.0768 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.4548 0.0776 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.4236 0.0563 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.4313 0.0763 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.3435 0.0765 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.3706 0.0764 sec/batch
# Nearest to use: common, used, similar, efficiently, has, much, multiple, include,
# Nearest to state: administration, government, legislative, council, states, approved, districts, agreement,
# Nearest to but: however, that, it, when, with, have, to, this,
# Nearest to where: is, a, above, it, these, number, an, also,
# Nearest to than: more, it, much, only, some, less, with, increase,
# Nearest to united: states, national, americans, department, republican, australia, nations, senior,
# Nearest to at: in, first, once, the, after, up, again, on,
# Nearest to s: was, in, on, a, the, of, as, first,
# Nearest to accepted: what, seek, that, criticised, necessary, should, not, those,
# Nearest to active: becoming, since, country, world, largely, excluding, presently, stalled,
# Nearest to discovered: known, it, planets, stars, is, found, clouds, unknown,
# Nearest to centre: city, located, streets, railroad, historic, downtown, tourist, residential,
# Nearest to taking: when, to, any, with, however, that, immediately, would,
# Nearest to lived: died, daughter, whom, sons, son, his, brother, death,
# Nearest to troops: army, forces, war, invasion, armies, fighting, fought, seized,
# Nearest to resources: increased, markets, economy, arable, infrastructure, sectors, facilities, sector,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4101 0.0779 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4008 0.0775 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.3327 0.0763 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.4187 0.0770 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.3759 0.0769 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.3955 0.0764 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.3302 0.0768 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.2907 0.0766 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.3063 0.0770 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.3159 0.0766 sec/batch
# Nearest to use: common, used, these, efficiently, standardized, providing, other, some,
# Nearest to state: administration, government, council, districts, legislative, constitution, states, executive,
# Nearest to but: it, with, some, that, be, not, however, this,
# Nearest to where: a, is, number, above, then, point, with, it,
# Nearest to than: more, much, less, it, with, only, this, because,
# Nearest to united: states, department, national, australia, british, commerce, america, companies,
# Nearest to at: once, first, after, soon, an, in, was, the,
# Nearest to s: was, nine, in, one, the, zero, on, a,
# Nearest to accepted: existence, view, seek, those, that, what, claim, reject,
# Nearest to active: currently, improved, providing, since, harvests, excluding, presently, sharply,
# Nearest to discovered: planets, nitric, solar, orbiting, discovery, clouds, astronomical, sun,
# Nearest to centre: located, residential, streets, downtown, city, largest, buildings, cities,
# Nearest to taking: when, leave, him, to, take, prevent, he, would,
# Nearest to lived: shrine, ptolemy, buried, reign, died, death, tribe, tomb,
# Nearest to troops: army, forces, armies, fighting, war, invasion, fought, soldiers,
# Nearest to resources: fisheries, environmental, economic, infrastructure, economy, hydropower, diversified, gnp,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.3359 0.0780 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.2960 0.0763 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.3220 0.0773 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.2581 0.0773 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3175 0.0769 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.3352 0.0775 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.2676 0.0774 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.2763 0.0772 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.2980 0.0776 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.2468 0.0775 sec/batch
# Nearest to use: common, standardized, systems, computers, basic, packages, used, users,
# Nearest to state: administration, law, council, legislative, departments, government, constitution, branch,
# Nearest to but: it, to, with, not, that, in, be, as,
# Nearest to where: a, left, is, above, then, points, right, number,
# Nearest to than: more, overall, less, it, only, larger, longer, much,
# Nearest to united: states, british, australia, national, federation, americans, america, department,
# Nearest to at: first, in, once, the, an, s, he, to,
# Nearest to s: one, in, nine, zero, a, was, two, the,
# Nearest to accepted: view, necessary, claim, beliefs, sense, seek, knowledge, necessarily,
# Nearest to active: currently, improved, presently, sharply, centers, stakeholders, providing, stalled,
# Nearest to discovered: planets, discovery, unknown, stars, discoveries, asteroid, faint, astronomical,
# Nearest to centre: residential, streets, redevelopment, building, located, buildings, downtown, historic,
# Nearest to taking: when, choose, take, any, leave, get, keep, left,
# Nearest to lived: sons, grandfather, shrine, daughter, died, fathered, whom, brother,
# Nearest to troops: army, armies, forces, surrender, fighting, invasion, soldiers, allied,
# Nearest to resources: allocation, economic, issues, liberalized, infrastructure, governmental, deregulation, economy,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.2512 0.0780 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.2815 0.0782 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.2733 0.0773 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.2461 0.0767 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.2990 0.0767 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.2379 0.0765 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.2659 0.0767 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.2807 0.0770 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.1859 0.0767 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.2346 0.0771 sec/batch
# Nearest to use: used, common, standardized, utilizing, flexibility, computers, systems, packages,
# Nearest to state: government, districts, law, municipal, jurisdiction, departments, states, federal,
# Nearest to but: it, that, in, to, with, had, however, as,
# Nearest to where: a, left, right, above, then, points, is, finally,
# Nearest to than: more, larger, much, less, slightly, it, only, overall,
# Nearest to united: states, federation, department, americans, national, citizens, america, nations,
# Nearest to at: in, first, the, s, once, over, one, to,
# Nearest to s: one, in, nine, of, a, zero, the, was,
# Nearest to accepted: view, sense, existence, beliefs, argued, understood, assert, contradict,
# Nearest to active: currently, presently, providing, improved, sharply, stakeholders, excluding, current,
# Nearest to discovered: planets, discovery, observed, discoveries, venus, unknown, astronomers, stars,
# Nearest to centre: residential, buildings, located, borough, building, redevelopment, centres, streets,
# Nearest to taking: when, leave, take, choose, him, get, left, prevent,
# Nearest to lived: his, sons, whom, daughter, tribe, grandfather, departed, shrine,
# Nearest to troops: forces, invasion, army, fighting, armies, surrender, fought, war,
# Nearest to resources: fisheries, markets, deregulation, hydropower, issues, economic, resource, tourism,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.2403 0.0777 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2039 0.0771 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.2996 0.0769 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.2828 0.0769 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.2915 0.0769 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.1839 0.0777 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.1774 0.0776 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.2441 0.0770 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.1299 0.0769 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.1799 0.0777 sec/batch
# Nearest to use: used, common, standardized, using, uses, utilizing, chipsets, tradeoffs,
# Nearest to state: districts, presides, states, governor, federal, statewide, municipal, legislative,
# Nearest to but: it, had, to, would, however, that, with, in,
# Nearest to where: a, above, left, then, is, right, points, direction,
# Nearest to than: more, less, larger, overall, vary, depend, it, longer,
# Nearest to united: states, nominees, secretaries, usa, department, commissioner, americans, jersey,
# Nearest to at: first, in, the, thirty, over, an, once, s,
# Nearest to s: in, a, the, was, of, nine, zero, with,
# Nearest to accepted: political, rejected, proposed, reform, asserted, democracy, establishment, advocating,
# Nearest to active: presently, currently, categorizations, excluding, sharply, collectivists, blocs, maintains,
# Nearest to discovered: planets, discovery, asteroid, discoveries, unknown, meteorite, distant, ganymede,
# Nearest to centre: buildings, residential, located, streets, building, thames, borough, centres,
# Nearest to taking: leave, choose, him, take, immediately, when, he, get,
# Nearest to lived: grandfather, remarried, his, sons, died, buried, whom, aunt,
# Nearest to troops: army, forces, invasion, surrender, armies, war, surrendered, fought,
# Nearest to resources: arable, resource, hydropower, pastures, fisheries, issues, irrigated, environment,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2042 0.0775 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2184 0.0767 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.2539 0.0361 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.1770 0.0767 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.1598 0.0766 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.1649 0.0766 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.1330 0.0759 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1245 0.0761 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.1555 0.0764 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1057 0.0773 sec/batch
# Nearest to use: used, common, standardized, etc, equipment, available, systems, standard,
# Nearest to state: districts, counties, municipal, mayors, legislative, municipalities, presides, district,
# Nearest to but: it, had, would, however, that, this, with, because,
# Nearest to where: above, then, left, a, sum, nth, direction, outer,
# Nearest to than: more, less, larger, much, overall, greater, compared, fewer,
# Nearest to united: states, nominees, mexico, usa, annex, jersey, americans, nafta,
# Nearest to at: in, the, first, an, second, over, after, completion,
# Nearest to s: was, a, in, nine, the, one, zero, this,
# Nearest to accepted: proposed, vehemently, advocating, calvinists, view, reform, disciplinary, yet,
# Nearest to active: currently, bulletin, stalled, providing, sig, fax, operational, subscription,
# Nearest to discovered: planets, discovery, meteorite, asteroid, unknown, discoveries, galileo, ganymede,
# Nearest to centre: residential, buildings, redevelopment, centres, streets, borough, downtown, located,
# Nearest to taking: leave, when, take, him, he, immediately, choose, asking,
# Nearest to lived: grandfather, buried, his, unknown, prosperous, ptolemy, settled, tomb,
# Nearest to troops: forces, army, surrender, war, fighting, surrendered, invasion, armies,
# Nearest to resources: arable, hydropower, usda, pastures, resource, economic, deregulation, irrigated,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.1977 0.0776 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.1867 0.0769 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.1677 0.0767 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.0818 0.0770 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1457 0.0764 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1261 0.0772 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1131 0.0767 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1230 0.0772 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1318 0.0767 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1146 0.0776 sec/batch
# Nearest to use: used, common, standardized, etc, widespread, usage, often, useful,
# Nearest to state: departments, districts, municipal, presides, statewide, federal, district, government,
# Nearest to but: it, however, would, be, to, this, because, that,
# Nearest to where: above, then, a, left, right, derivative, sum, circle,
# Nearest to than: more, less, much, larger, fewer, only, compared, slightly,
# Nearest to united: states, mexico, nominees, america, jersey, recipients, americans, annex,
# Nearest to at: in, an, the, after, second, thirty, first, once,
# Nearest to s: nine, a, one, zero, was, in, the, eight,
# Nearest to accepted: adherence, view, legalistic, interpretation, reform, advocating, calvinists, determinations,
# Nearest to active: currently, globalsecurity, incubator, romandy, electorates, presently, operational, volunteers,
# Nearest to discovered: planets, discovery, asteroid, unknown, meteorite, orbiting, astronomers, lacaille,
# Nearest to centre: residential, centres, buildings, boulevards, redevelopment, streets, located, borough,
# Nearest to taking: when, take, leave, him, choose, finally, get, left,
# Nearest to lived: grandfather, his, died, buried, interred, wedlock, aunt, meadows,
# Nearest to troops: forces, army, fighting, allied, surrender, war, armies, surrendered,
# Nearest to resources: resource, arable, hydropower, pastures, logging, irrigated, environmental, woodland,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1068 0.0777 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.1928 0.0774 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.0996 0.0786 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.0830 0.0766 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1013 0.0765 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1271 0.0782 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1307 0.0767 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.0760 0.0769 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.0776 0.0767 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1108 0.0771 sec/batch
# Nearest to use: used, invoices, standardized, equipment, common, utilizing, using, usage,
# Nearest to state: districts, departments, statewide, municipal, counties, government, jurisdiction, mayors,
# Nearest to but: it, be, that, to, because, this, not, however,
# Nearest to where: sum, left, then, arctan, a, above, pi, right,
# Nearest to than: more, less, greater, much, larger, fewer, compared, only,
# Nearest to united: states, nominees, americans, mexico, jersey, recipients, america, usa,
# Nearest to at: in, thirty, the, once, an, first, s, to,
# Nearest to s: a, in, nine, one, zero, the, with, eight,
# Nearest to accepted: proposed, interpretation, calvinists, promulgated, progressives, yet, rejected, heresies,
# Nearest to active: currently, globalsecurity, collectivists, electorates, presently, locksmith, legalize, maintains,
# Nearest to discovered: discovery, planets, discoveries, asteroid, unknown, galileo, lacaille, venus,
# Nearest to centre: residential, centres, redevelopment, boulevards, buildings, borough, building, conurbation,
# Nearest to taking: when, take, leave, him, choose, left, finally, where,
# Nearest to lived: grandfather, his, aunt, death, sisters, wedlock, grandmother, fathered,
# Nearest to troops: army, forces, allied, fighting, rebels, soldiers, armies, surrendered,
# Nearest to resources: resource, arable, comprehensive, hydropower, web, pastures, environment, portals,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1358 0.0780 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1028 0.0768 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1001 0.0769 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1278 0.0772 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.0794 0.0777 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.0748 0.0764 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1147 0.0772 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.0639 0.0768 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1265 0.0773 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1648 0.0767 sec/batch
# Nearest to use: used, common, usage, invoices, deprecated, standardized, using, commonly,
# Nearest to state: districts, statewide, departments, legislators, democrats, government, counties, councilors,
# Nearest to but: it, had, however, because, to, as, that, this,
# Nearest to where: sum, left, a, then, right, fraternity, taking, pi,
# Nearest to than: more, much, compared, less, greater, fewer, only, nonetheless,
# Nearest to united: states, nominees, americans, mexico, secretaries, usa, jersey, episcopalians,
# Nearest to at: in, thirty, majored, nottingham, years, an, lakeview, first,
# Nearest to s: a, in, was, the, with, nine, of, one,
# Nearest to accepted: proposed, interpretation, view, homily, controversy, disciplinary, heretical, hypotheses,
# Nearest to active: currently, secessionist, globalsecurity, kuwaitis, islamists, farc, objectors, presently,
# Nearest to discovered: discovery, discoveries, unknown, planets, lacaille, asteroid, galileo, astronomer,
# Nearest to centre: centres, residential, boulevards, conurbation, redevelopment, borough, buildings, london,
# Nearest to taking: him, where, he, left, resigned, get, begin, leave,
# Nearest to lived: grandfather, his, cyprian, wealthy, prosperous, aunt, childhood, whom,
# Nearest to troops: army, forces, allied, surrender, retreated, surrendered, war, fighting,
# Nearest to resources: arable, hydropower, resource, pastures, irrigated, exploitation, natural, phosphates,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.1753 0.0778 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.0649 0.0772 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.0864 0.0767 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1031 0.0763 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 3.9843 0.0770 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.0879 0.0770 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.0720 0.0762 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.0714 0.0769 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1444 0.0151 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0596 0.0766 sec/batch
# Nearest to use: used, common, using, usage, standardized, equipment, similar, deprecated,
# Nearest to state: counties, districts, statewide, states, delaware, democrats, councilors, iowa,
# Nearest to but: it, however, because, had, with, that, to, not,
# Nearest to where: sum, a, prod, fraca, nth, left, arctan, above,
# Nearest to than: less, more, much, compared, fewer, considerably, greater, larger,
# Nearest to united: states, nominees, usa, americans, jersey, mexico, department, recipients,
# Nearest to at: second, in, twice, thirty, the, an, over, once,
# Nearest to s: a, was, the, in, with, nine, following, zero,
# Nearest to accepted: ltv, proposed, subjectivism, challenged, possibility, disagreement, advocating, pragmatism,
# Nearest to active: currently, presently, kuwaitis, globalsecurity, malays, secessionist, excluding, islamists,
# Nearest to discovered: discovery, planets, discoveries, asteroid, unknown, probes, ganymede, meteorite,
# Nearest to centre: centres, residential, redevelopment, boulevards, buildings, conurbation, borough, plaza,
# Nearest to taking: choose, inability, finally, get, pernicious, take, him, hopeless,
# Nearest to lived: grandfather, brook, studied, wealthy, pytheas, his, worked, cyprian,
# Nearest to troops: forces, army, surrendered, allied, surrender, evacuated, war, evacuation,
# Nearest to resources: arable, hydropower, resource, pastures, exploitation, irrigated, logging, phosphates,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0221 0.0775 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0176 0.0768 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0528 0.0769 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
